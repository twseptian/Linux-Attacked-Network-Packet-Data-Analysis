# %%
import pandas as pd
df=pd.read_table("frame.len")

# %%
df.head()
# Out:
#    frame.number  frame.len
# 0             1         60
# 1             2         60
# 2             3         60
# 3             4         60
# 4             5         83

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
infodata = df["frame.len"].plot(style=".", alpha=0.2,figsize=(20,20),title="Frame Length Attack Linux")
infodata.set_ylabel("bytes")
infodata.set_xlabel("frame number")

# %%
fig = infodata.get_figure()
fig.savefig("Frame Length Attack Linux.png")
