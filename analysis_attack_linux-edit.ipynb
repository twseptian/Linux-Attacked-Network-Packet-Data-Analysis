# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
allattack=pd.read_csv("csv_attack_linux_pcap.csv", parse_dates=['Time'])
allattack.head()
# Out:
#    No.                       Time             Source        Destination  \
# 0    1 2011-11-16 16:36:31.418872  Micro-St_60:f7:fb          Broadcast
# 1    2 2011-11-16 16:36:31.418892  Micro-St_60:f8:09  Micro-St_60:f7:fb
# 2    3 2011-11-16 16:36:31.423539  Micro-St_60:f7:fb          Broadcast
# 3    4 2011-11-16 16:36:31.423554      3com_68:a6:95  Micro-St_60:f7:fb
# 4    5 2011-11-16 16:36:31.423557        10.10.10.20      161.139.250.2
#
#   Protocol  Length                                               Info
# 0      ARP      60              Who has 10.10.10.5?  Tell 10.10.10.20
# 1      ARP      60                 10.10.10.5 is at 00:11:09:60:f8:09
# 2      ARP      60              Who has 10.10.10.1?  Tell 10.10.10.20
# 3      ARP      60                 10.10.10.1 is at 00:50:04:68:a6:95
# 4      DNS      83  Standard query 0xab42  PTR 5.10.10.10.in-addr....

# %%
allattack.describe()
# Out:
#                   No.          Length
# count  2331445.000000  2331445.000000
# mean   1165723.000000      419.617014
# std     673030.343513      586.156941
# min          1.000000       42.000000
# 25%     582862.000000       62.000000
# 50%    1165723.000000       74.000000
# 75%    1748584.000000      610.000000
# max    2331445.000000     1514.000000

# %%
infodata = allattack[['Time','Source','Destination','Protocol',
                  'Length','Info']]

# %%
infodata
# Out:
#                               Time             Source        Destination  \
# 0       2011-11-16 16:36:31.418872  Micro-St_60:f7:fb          Broadcast
# 1       2011-11-16 16:36:31.418892  Micro-St_60:f8:09  Micro-St_60:f7:fb
# 2       2011-11-16 16:36:31.423539  Micro-St_60:f7:fb          Broadcast
# 3       2011-11-16 16:36:31.423554      3com_68:a6:95  Micro-St_60:f7:fb
# 4       2011-11-16 16:36:31.423557        10.10.10.20      161.139.250.2
# 5       2011-11-16 16:36:31.425407      161.139.250.2        10.10.10.20
# 6       2011-11-16 16:36:31.426717        10.10.10.20         10.10.10.5
# 7       2011-11-16 16:36:31.426727        10.10.10.20         10.10.10.5
# 8       2011-11-16 16:36:31.427580         10.10.10.5        10.10.10.20
# 9       2011-11-16 16:36:31.427589         10.10.10.5        10.10.10.20
# 10      2011-11-16 16:36:31.427592        10.10.10.20         10.10.10.5
# 11      2011-11-16 16:36:31.427881        10.10.10.20         10.10.10.5
# 12      2011-11-16 16:36:31.427891         10.10.10.5        10.10.10.20
# 13      2011-11-16 16:36:31.427894         10.10.10.5        10.10.10.20
# 14      2011-11-16 16:36:31.428131        10.10.10.20         10.10.10.5
# 15      2011-11-16 16:36:31.428141        10.10.10.20         10.10.10.5
# 16      2011-11-16 16:36:31.428366         10.10.10.5        10.10.10.20
# 17      2011-11-16 16:36:31.428376         10.10.10.5        10.10.10.20
# 18      2011-11-16 16:36:31.428730        10.10.10.20         10.10.10.5
# 19      2011-11-16 16:36:31.428739        10.10.10.20         10.10.10.5
# 20      2011-11-16 16:36:31.428742         10.10.10.5        10.10.10.20
# 21      2011-11-16 16:36:31.428745         10.10.10.5        10.10.10.20
# 22      2011-11-16 16:36:31.428961        10.10.10.20         10.10.10.5
# 23      2011-11-16 16:36:31.428970        10.10.10.20         10.10.10.5
# 24      2011-11-16 16:36:31.428973         10.10.10.5        10.10.10.20
# 25      2011-11-16 16:36:31.429255         10.10.10.5        10.10.10.20
# 26      2011-11-16 16:36:31.429264        10.10.10.20         10.10.10.5
# 27      2011-11-16 16:36:31.429267        10.10.10.20         10.10.10.5
# 28      2011-11-16 16:36:31.429270        10.10.10.20         10.10.10.5
# 29      2011-11-16 16:36:31.429490        10.10.10.20         10.10.10.5
# ...                            ...                ...                ...
# 2331415 2011-11-16 18:42:19.824183        10.10.10.20         10.10.10.5
# 2331416 2011-11-16 18:42:19.824192         10.10.10.5        10.10.10.20
# 2331417 2011-11-16 18:42:19.825612        10.10.10.20         10.10.10.5
# 2331418 2011-11-16 18:42:19.825622         10.10.10.5        10.10.10.20
# 2331419 2011-11-16 18:42:19.830412        10.10.10.20         10.10.10.5
# 2331420 2011-11-16 18:42:19.830419         10.10.10.5        10.10.10.20
# 2331421 2011-11-16 18:42:19.830670        10.10.10.20         10.10.10.5
# 2331422 2011-11-16 18:42:19.830677         10.10.10.5        10.10.10.20
# 2331423 2011-11-16 18:42:19.833603        10.10.10.20         10.10.10.5
# 2331424 2011-11-16 18:42:19.894651        10.10.10.20         10.10.10.5
# 2331425 2011-11-16 18:42:19.894989         10.10.10.5        10.10.10.20
# 2331426 2011-11-16 18:42:19.894999        10.10.10.20         10.10.10.5
# 2331427 2011-11-16 18:42:19.896080        10.10.10.20         10.10.10.5
# 2331428 2011-11-16 18:42:19.896089         10.10.10.5        10.10.10.20
# 2331429 2011-11-16 18:42:19.900980        10.10.10.20         10.10.10.5
# 2331430 2011-11-16 18:42:19.900989         10.10.10.5        10.10.10.20
# 2331431 2011-11-16 18:42:19.900992        10.10.10.20         10.10.10.5
# 2331432 2011-11-16 18:42:19.902398         10.10.10.5        10.10.10.20
# 2331433 2011-11-16 18:42:19.902407        10.10.10.20         10.10.10.5
# 2331434 2011-11-16 18:42:19.902410        10.10.10.20         10.10.10.5
# 2331435 2011-11-16 18:42:19.902666         10.10.10.5        10.10.10.20
# 2331436 2011-11-16 18:42:19.904269         10.10.10.5        10.10.10.20
# 2331437 2011-11-16 18:42:19.906675        10.10.10.20         10.10.10.5
# 2331438 2011-11-16 18:42:19.940931         10.10.10.5        10.10.10.20
# 2331439 2011-11-16 18:42:19.941866        10.10.10.20         10.10.10.5
# 2331440 2011-11-16 18:42:19.980984         10.10.10.5        10.10.10.20
# 2331441 2011-11-16 18:42:19.982676        10.10.10.20         10.10.10.5
# 2331442 2011-11-16 18:42:19.982686         10.10.10.5        10.10.10.20
# 2331443 2011-11-16 18:42:19.991794         10.10.10.5        10.10.10.20
# 2331444 2011-11-16 18:42:20.030278        10.10.10.20         10.10.10.5
#
#         Protocol  Length                                               Info
# 0            ARP      60              Who has 10.10.10.5?  Tell 10.10.10.20
# 1            ARP      60                 10.10.10.5 is at 00:11:09:60:f8:09
# 2            ARP      60              Who has 10.10.10.1?  Tell 10.10.10.20
# 3            ARP      60                 10.10.10.1 is at 00:50:04:68:a6:95
# 4            DNS      83  Standard query 0xab42  PTR 5.10.10.10.in-addr....
# 5            DNS     134        Standard query response 0xab42 No such name
# 6            TCP      60   33958 > 5900 [SYN] Seq=0 Win=1024 Len=0 MSS=1460
# 7            TCP      60    33958 > 135 [SYN] Seq=0 Win=3072 Len=0 MSS=1460
# 8            TCP      60    5900 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 9            TCP      60     135 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 10           TCP      60    33958 > 554 [SYN] Seq=0 Win=1024 Len=0 MSS=1460
# 11           TCP      60    33958 > 995 [SYN] Seq=0 Win=2048 Len=0 MSS=1460
# 12           TCP      60     554 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 13           TCP      60     995 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 14           TCP      60     33958 > 80 [SYN] Seq=0 Win=2048 Len=0 MSS=1460
# 15           TCP      60   33958 > 8888 [SYN] Seq=0 Win=4096 Len=0 MSS=1460
# 16           TCP      60  80 > 33958 [SYN, ACK] Seq=0 Ack=1 Win=5840 Len...
# 17           TCP      60    8888 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 18           TCP      60    33958 > 993 [SYN] Seq=0 Win=3072 Len=0 MSS=1460
# 19           TCP      60   33958 > 3306 [SYN] Seq=0 Win=2048 Len=0 MSS=1460
# 20           TCP      60     993 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 21           TCP      60  3306 > 33958 [SYN, ACK] Seq=0 Ack=1 Win=5840 L...
# 22           TCP      60     33958 > 53 [SYN] Seq=0 Win=1024 Len=0 MSS=1460
# 23           TCP      60    33958 > 139 [SYN] Seq=0 Win=4096 Len=0 MSS=1460
# 24           TCP      60      53 > 33958 [RST, ACK] Seq=1 Ack=1 Win=0 Len=0
# 25           TCP      60  139 > 33958 [SYN, ACK] Seq=0 Ack=1 Win=5840 Le...
# 26           TCP      60                 33958 > 80 [RST] Seq=1 Win=0 Len=0
# 27           TCP      60               33958 > 3306 [RST] Seq=1 Win=0 Len=0
# 28           TCP      60                33958 > 139 [RST] Seq=1 Win=0 Len=0
# 29           TCP      60   33958 > 8080 [SYN] Seq=0 Win=2048 Len=0 MSS=1460
# ...          ...     ...                                                ...
# 2331415      TCP      66  54245 > 22 [ACK] Seq=1 Ack=1 Win=5888 Len=0 TS...
# 2331416      TCP      66  22 > 54245 [FIN, ACK] Seq=1 Ack=1 Win=5792 Len...
# 2331417    SSHv2      90          Client: Protocol (SSH-2.0-paramiko_1.5.2)
# 2331418      TCP      60                 22 > 54245 [RST] Seq=2 Win=0 Len=0
# 2331419      TCP      74  [TCP Port numbers reused] 54246 > 22 [SYN] Seq...
# 2331420      TCP      74  22 > 54246 [SYN, ACK] Seq=0 Ack=1 Win=5792 Len...
# 2331421      TCP      66  54246 > 22 [ACK] Seq=1 Ack=1 Win=5888 Len=0 TS...
# 2331422      TCP      66  22 > 54246 [FIN, ACK] Seq=1 Ack=1 Win=5792 Len...
# 2331423      TCP      66  54246 > 22 [ACK] Seq=1 Ack=2 Win=5888 Len=0 TS...
# 2331424      TCP      66  54230 > 22 [FIN, ACK] Seq=649 Ack=1168 Win=806...
# 2331425      TCP      66  22 > 54230 [FIN, ACK] Seq=1168 Ack=650 Win=643...
# 2331426      TCP      66  54230 > 22 [ACK] Seq=650 Ack=1169 Win=8064 Len...
# 2331427    SSHv2      90          Client: Protocol (SSH-2.0-paramiko_1.5.2)
# 2331428      TCP      60                 22 > 54246 [RST] Seq=2 Win=0 Len=0
# 2331429      TCP      74  [TCP Port numbers reused] 54247 > 22 [SYN] Seq...
# 2331430      TCP      74  22 > 54247 [SYN, ACK] Seq=0 Ack=1 Win=5792 Len...
# 2331431      TCP      66  54247 > 22 [ACK] Seq=1 Ack=1 Win=5888 Len=0 TS...
# 2331432    SSHv2      89          Server: Protocol (SSH-1.99-OpenSSH_3.5p1)
# 2331433      TCP      66  54247 > 22 [ACK] Seq=1 Ack=24 Win=5888 Len=0 T...
# 2331434    SSHv2      90          Client: Protocol (SSH-2.0-paramiko_1.5.2)
# 2331435      TCP      66  22 > 54247 [ACK] Seq=24 Ack=25 Win=5792 Len=0 ...
# 2331436    SSHv2     610                          Server: Key Exchange Init
# 2331437    SSHv2     394                          Client: Key Exchange Init
# 2331438      TCP      66  22 > 54247 [ACK] Seq=568 Ack=353 Win=6432 Len=...
# 2331439    SSHv2     166                 Client: Encrypted packet (len=100)
# 2331440      TCP      66  22 > 54237 [ACK] Seq=1084 Ack=665 Win=6432 Len...
# 2331441    SSHv2     210           Client: Diffie-Hellman Key Exchange Init
# 2331442      TCP      66  22 > 54244 [ACK] Seq=568 Ack=497 Win=6432 Len=...
# 2331443    SSHv2     530  Server: Diffie-Hellman Key Exchange Reply, New...
# 2331444      TCP      66  54244 > 22 [ACK] Seq=497 Ack=1032 Win=8064 Len...
#
# [2331445 rows x 6 columns]

# %%
category_group=infodata.groupby(['Source','Destination','Protocol']).sum()
category_group
# Out:
#                                                           Length
# Source                    Destination       Protocol
# 10.10.10.1                10.10.10.15       TCP              360
# 10.10.10.15               10.10.10.1        TCP              372
#                           10.10.10.20       ICMP             120
#                                             TCP              372
#                                             UDP               60
#                           10.10.10.255      BROWSER         4633
#                                             NBNS            4140
#                           10.10.10.30       TCP              310
#                           10.10.10.5        802.11           258
#                                             ALLJOYN-NS        69
#                                             ANSI C12.22       60
#                                             AODV            4536
#                                             ASF              240
#                                             ASTERIX           69
#                                             AX4000            69
#                                             AYIYA             69
#                                             Auto-RP         4536
#                                             BAT_BATMAN        69
#                                             BAT_GW            60
#                                             BAT_VIS           69
#                                             BFD Control      285
#                                             BJNP             240
#                                             BOOTP          10274
#                                             CAPWAP           120
#                                             CLASSIC-STUN     210
#                                             CLDAP           4750
#                                             CN/IP            129
#                                             CUPS            4536
#                                             CoAP              60
#                                             DAYTIME        57363
# ...                                                          ...
# 67.201.31.64              10.10.10.15       HTTP             176
#                                             TCP            47892
# 72.3.245.172              10.10.10.15       HTTP             383
#                                             TCP              182
# 74.125.39.113             10.10.10.15       HTTP            1440
#                                             TCP             2178
# 74.125.39.120             10.10.10.15       TCP              702
#                                             TLSv1          67088
# 74.125.39.138             10.10.10.15       HTTP            1188
#                                             TCP             2568
#                                             TLSv1           3416
# 76:20:69:63:6d:70         70:69:6e:67:20:2d 0x2031            69
# 77.67.96.198              10.10.10.30       HTTP            4279
#                                             TCP            29733
# 87.230.63.11              10.10.10.15       TCP             2990
# Micro-St_60:f7:fb         3com_68:a6:95     ARP              360
#                           Broadcast         ARP             9660
#                           Micro-St_60:f8:09 ARP              840
#                           Tp-LinkT_b5:79:3f ARP              180
# Micro-St_60:f8:09         Broadcast         ARP               60
#                           Micro-St_60:f7:fb ARP             1260
#                           Tp-LinkT_b5:79:3f ARP             2700
# Supermic_df:55:10         3com_68:a6:95     ARP              756
#                           Tp-LinkT_b5:79:3f ARP              126
# Tp-LinkT_b5:79:3f         3com_68:a6:95     ARP             1440
#                           Broadcast         ARP            55380
#                           Micro-St_60:f7:fb ARP               60
#                           Micro-St_60:f8:09 ARP             2040
#                           Supermic_df:55:10 ARP               60
# fe80::8000:5445:5245:444f ff02::2           ICMPv6           103
#
# [349 rows x 1 columns]

# %%
category_group.unstack().head()
# Out:
#                           Length                                              \
# Protocol                  0x2031  802.11  ALLJOYN-NS  ANSI C12.22  AODV  ARP
# Source      Destination
# 10.10.10.1  10.10.10.15      NaN     NaN         NaN          NaN   NaN  NaN
# 10.10.10.15 10.10.10.1       NaN     NaN         NaN          NaN   NaN  NaN
#             10.10.10.20      NaN     NaN         NaN          NaN   NaN  NaN
#             10.10.10.255     NaN     NaN         NaN          NaN   NaN  NaN
#             10.10.10.30      NaN     NaN         NaN          NaN   NaN  NaN
#
#                                                        ...              \
# Protocol                  ASF  ASTERIX  AX4000  AYIYA  ...    WTLS+WSP
# Source      Destination                                ...
# 10.10.10.1  10.10.10.15   NaN      NaN     NaN    NaN  ...         NaN
# 10.10.10.15 10.10.10.1    NaN      NaN     NaN    NaN  ...         NaN
#             10.10.10.20   NaN      NaN     NaN    NaN  ...         NaN
#             10.10.10.255  NaN      NaN     NaN    NaN  ...         NaN
#             10.10.10.30   NaN      NaN     NaN    NaN  ...         NaN
#
#                                                                               \
# Protocol                  WTLS+WTP+WSP  WTP+WSP  X11  XDMCP  XTACACS  XYPLEX
# Source      Destination
# 10.10.10.1  10.10.10.15            NaN      NaN  NaN    NaN      NaN     NaN
# 10.10.10.15 10.10.10.1             NaN      NaN  NaN    NaN      NaN     NaN
#             10.10.10.20            NaN      NaN  NaN    NaN      NaN     NaN
#             10.10.10.255           NaN      NaN  NaN    NaN      NaN     NaN
#             10.10.10.30            NaN      NaN  NaN    NaN      NaN     NaN
#
#
# Protocol                  collectd  lw_res  packetbb
# Source      Destination
# 10.10.10.1  10.10.10.15        NaN     NaN       NaN
# 10.10.10.15 10.10.10.1         NaN     NaN       NaN
#             10.10.10.20        NaN     NaN       NaN
#             10.10.10.255       NaN     NaN       NaN
#             10.10.10.30        NaN     NaN       NaN
#
# [5 rows x 152 columns]

# %%
my_plot = category_group.plot(kind='barh',stacked=True,title="Total Packet Protocol Data",figsize=(30,100))
my_plot.set_xlabel("Length Protocol")
my_plot.set_ylabel("Source IP - Destination IP")

# %%
my_plot = category_group.unstack().plot(kind='barh',stacked=True,title="Total Protocol",figsize=(20, 20))
my_plot.set_xlabel("IP address")
my_plot.set_ylabel("Protocol")
patches, labels = my_plot.get_legend_handles_labels()
my_plot.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=8, title="Protocol")
